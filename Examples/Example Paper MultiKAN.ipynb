# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import openai
import os
from llmlex.kanlex import KANLEX
import llmlex

# %%
client = openai.OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY") if os.getenv("OPENROUTER_API_KEY") else "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",
)
llmlex.llm.check_key_limit(client)
# Out:
# 77.24330025

# %% [markdown]
# # Example 1

# %%
def multivariate_function(x):
    return torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)

# Initialize a KANSR instance for the multivariate function
multivariate_kansr = KANLEX(
    client=client,
    width=[2, 3, 1],
    grid=7,
    k=3,
    seed=0
)

multivariate_dataset = multivariate_kansr.create_dataset(
    f=multivariate_function,
    ranges=(-1, 1),
    n_var=2,
    train_num=10000,
    test_num=1000
)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
multivariate_kansr.train_kan(
    dataset=multivariate_dataset,
    opt="LBFGS",
    steps=50,
    prune=True,
    node_th=0.2,
    edge_th=0.2
)
# Out:
# 2025-04-12 13:41:42,333 - LLMLEx.kanLEx - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 1.71e-03 | test_loss: 1.71e-03 | reg: 1.18e+01 | : 100%|█| 50/50 [00:10<00:00,  4.65it
# saving model version 0.1
# Unpruned model. Pruning? True
# 2025-04-12 13:41:53,626 - LLMLEx.kanLEx - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-04-12 13:41:53,634 - LLMLEx.kanLEx - INFO - Pruned model:
# 2025-04-12 13:41:53,806 - LLMLEx.kanLEx - INFO - Final train loss: 0.0017132654320448637
# saving model version 0.2
# 0.0017132654320448637

# %%
best_expressions, best_chi_squareds, results_dicts, results_all_dicts = multivariate_kansr.get_symbolic(
    client=client,
    population=3,
    generations=2,
    temperature=0.1,
    gpt_model="openai/gpt-5-nano-2025-08-07",
    verbose=1,
    use_async=True,
    plot_fit=True,
    plot_parents=True,
    demonstrate_parent_plotting=True
)
# Out:
# 2025-04-12 13:41:54,319 - LLMLEx.kanLEx - WARNING - Using default exit condition of 0.001. Consider passing 'overall_nchi_squared'as an exit condition - this is the n_chi_squared of the entire model on its inputs. It's not the default as this is not necessarily meaningful for each individual activation function.
# 2025-04-12 13:41:54,320 - LLMLEx.kanLEx - INFO - Converting KAN model to symbolic expressions (exit_condition=0.001)
# 2025-04-12 13:41:54,439 - llmlex.llmlex - INFO - Processing KAN model connections
# 2025-04-12 13:41:54,441 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,0,0)
# 2025-04-12 13:41:54,539 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,0,0)
# 2025-04-12 13:41:54,768 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -0.9965788722038269, for constant: [-0.04952487]
# 2025-04-12 13:41:54,768 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:41:57,360 - llmlex.llmlex - INFO - Generated 3 individuals
# 2025-04-12 13:41:57,361 - llmlex.llmlex - INFO - Initial population best: score=-1.2292530300328508e-06, params=[-1.02229130e-01 -3.14643995e+00  7.01311651e-04 -4.84811370e-02], ansatz: params[0] * np.sin(params[1] * x) + params[2] * x + params[3]...
# 2025-04-12 13:41:57,362 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-04-12 13:41:57,362 - llmlex.llmlex - INFO - Successfully found expression for connection (0,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 3
#   Failed calls: 0
#   Success rate: 100.00%
#
# Breakdown by processing stage:
#   Api Call: 3 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 3 succeeded, 0 failed (100.00% success)
#   Function Conversion: 3 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 3 succeeded, 0 failed (100.00% success)
#
# Error types:
#   No errors
# Approximation for (0,0,0): params[0] * np.sin(params[1] * x) + params[2] * x + params[3], with score -1.2292530300328508e-06 and parameters [-1.020e-01 -3.146e+00  1.000e-03 -4.800e-02]
# 2025-04-12 13:41:57,464 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,1,0)
# 2025-04-12 13:41:57,527 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,1,0)
# 2025-04-12 13:41:57,529 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.8307503461837769, for constant: [-0.07957751]
# 2025-04-12 13:41:57,529 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:41:59,414 - llmlex.llmlex - INFO - Generated 3 individuals
# 2025-04-12 13:41:59,415 - llmlex.llmlex - INFO - Initial population best: score=-3.6295352856541285e-06, params=[ 1.02361369e-01  3.62543723e-05 -1.14576013e-01], ansatz: params[0] * x**2 + params[1] * x + params[2]...
# 2025-04-12 13:41:59,416 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-04-12 13:41:59,417 - llmlex.llmlex - INFO - Successfully found expression for connection (0,1,0)
# API Call Statistics:
#   Successful calls (end-to-end): 3
#   Failed calls: 0
#   Success rate: 100.00%
#
# Breakdown by processing stage:
#   Api Call: 3 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 3 succeeded, 0 failed (100.00% success)
#   Function Conversion: 3 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 3 succeeded, 0 failed (100.00% success)
#
# Error types:
#   No errors
# Approximation for (0,1,0): params[0] * x**2 + params[1] * x + params[2], with score -3.6295352856541285e-06 and parameters [ 0.102  0.    -0.115]
# 2025-04-12 13:41:59,522 - llmlex.llmlex - INFO - Processing non-symbolic activation function (1,0,0)
# 2025-04-12 13:41:59,588 - llmlex.llmlex - INFO - Running genetic algorithm for connection (1,0,0)
# 2025-04-12 13:41:59,589 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -3.047534704208374, for constant: [1.71331981]
# 2025-04-12 13:41:59,589 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:42:01,534 - llmlex.llmlex - INFO - Generated 3 individuals
# 2025-04-12 13:42:01,535 - llmlex.llmlex - INFO - Initial population best: score=-0.002142505021765828, params=[ 4.79627826 10.39422849], ansatz: params[0] * np.exp(params[1] * x)...
# 2025-04-12 13:42:01,612 - llmlex.llmlex - INFO - Generation 1/1: Generating 3 new individuals. Elitism? False
# 2025-04-12 13:42:02,766 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with this request.'
# 2025-04-12 13:42:04,463 - llmlex.llmlex - INFO - Generation 1 best: score=-7.979143265401945e-05, params=[ 4.77858383 10.13032367 -1.58221727], ansatz: params[0] * np.exp(params[1] * x) + params[2] * x**2...
# 2025-04-12 13:42:04,464 - llmlex.llmlex - INFO - Exit condition met after generation 1: -7.979143265401945e-05>-0.001
# 2025-04-12 13:42:04,465 - llmlex.llmlex - INFO - Successfully found expression for connection (1,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 6
#   Failed calls: 1
#   Success rate: 85.71%
#
# Breakdown by processing stage:
#   Api Call: 7 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 6 succeeded, 1 failed (85.71% success)
#   Function Conversion: 6 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 6 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 1
# Approximation for (1,0,0): params[0] * np.exp(params[1] * x) + params[2] * x**2, with score -7.979143265401945e-05 and parameters [ 4.779 10.13  -1.582]
# 2025-04-12 13:42:04,573 - llmlex.llmlex - INFO - KAN conversion complete: 3 total connections
# 2025-04-12 13:42:04,573 - llmlex.llmlex - INFO - Connection breakdown: 0 symbolic, 0 zero, 3 processed
# 2025-04-12 13:42:04,759 - llmlex.llmlex - INFO - API key usage whilst this kan_to_symbolic was running: $0.00
# 2025-04-12 13:42:04,760 - LLMLEx.kanLEx - INFO - Approximation for (0, 0, 0): params[0] * np.sin(params[1] * x) + params[2] * x + params[3], has parameters [-0.1 -3.1  0.  -0. ]
# 2025-04-12 13:42:04,761 - LLMLEx.kanLEx - INFO - Approximation for (0, 1, 0): params[0] * x**2 + params[1] * x + params[2], has parameters [ 0.1  0.  -0.1]
# 2025-04-12 13:42:04,762 - LLMLEx.kanLEx - INFO - Approximation for (1, 0, 0): params[0] * np.exp(params[1] * x) + params[2] * x**2, has parameters [ 4.8 10.1 -1.6]
# 2025-04-12 13:42:04,762 - LLMLEx.kanLEx - INFO - Building expression tree
# 2025-04-12 13:42:04,763 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 0, 0), Best Expression: -0.1022291302542226 * np.sin(-3.1464399517800281 * x ) + 0.0007013116506100 * x + -0.0484811370389283, Score: -0.00000
# 2025-04-12 13:42:04,764 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 1, 0), Best Expression: 0.1023613687550322 * x**2 + 0.0000362543722678 * x + -0.1145760129165073, Score: -0.00000
# 2025-04-12 13:42:04,764 - LLMLEx.kanLEx - INFO - KAN Connection: (1, 0, 0), Best Expression: 4.7785838323017318 * np.exp(10.1303236673928065 * x ) + -1.5822172692423788 * x**2, Score: -0.00008
# 2025-04-12 13:42:04,768 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 4.7785838323017318 * sp.exp(10.1303236673928065 * (-0.1022291302542226 * sp.sin(-3.1464399517800281 * x0 ) + 0.0007013116506100 * x0 - 0.0484811370389283 + 0.1023613687550322 * x1**2 + 0.0000362543722678 * x1 - 0.1145760129165073) ) - 1.5822172692423788 * (-0.1022291302542226 * sp.sin(-3.1464399517800281 * x0 ) + 0.0007013116506100 * x0 - 0.0484811370389283 + 0.1023613687550322 * x1**2 + 0.0000362543722678 * x1 - 0.1145760129165073)**2
# 2025-04-12 13:42:13,575 - LLMLEx.kanLEx - INFO -
# ###################################################
# 2025-04-12 13:42:13,575 - LLMLEx.kanLEx - INFO - Simplifying output 0 using openai/gpt-5-nano-2025-08-07 and sympy
# 2025-04-12 13:42:13,925 - LLMLEx.kanLEx - INFO - KAN expression (raw), n_chi2 with original data: 5.5785e+00: -0.04207*(0.004301*x0 + 0.6278*x1**2 + 0.0002223*x1 + 0.627*sin(3.146*x0) - 1)**2 + 0.9161*exp(0.007105*x0 + 1.037*x1**2 + 0.0003673*x1 + 1.036*sin(3.146*x0))
# 2025-04-12 13:42:13,926 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: -0.0420674139029432*(0.0043010174702653*x0 + 0.6277637551190370*x1**2 + 0.0002223415058935*x1 + 0.6269527603184670*sp.sin(3.1464399517800299*x0) - 1.0000000000000000)**2 + 0.9160562827758369*sp.exp(0.0071045140123928*x0 + 1.0369537965258300*x1**2 + 0.0003672685254310*x1 + 1.0356141777113299*sp.sin(3.1464399517800299*x0))
# 2025-04-12 13:42:16,059 - LLMLEx.kanLEx - INFO - Expression (raw expression (simplified)) maintains similar n_chi2: 5.5785e+00
# 2025-04-12 13:42:16,136 - LLMLEx.kanLEx - INFO - Refitting simplified expression, trying to improve n_chi2 from 5.5785e+00, params[0]*(params[2]*x0 + params[5]*x1**2 + params[3]*x1 + params[7]*np.sin(params[8]*x0) - params[11])**2 + params[4]*np.exp(params[1]*x0 + params[10]*x1**2 + params[6]*x1 + params[9]*np.sin(params[8]*x0)), [-0.0420674139029432, 0.0071045140123928, 0.0043010174702653, 0.0002223415058935, 0.916056282775837, 0.627763755119037, 0.000367268525431, 0.626952760318467, 3.14643995178003, 1.03561417771133, 1.03695379652583, 1.0], <function <lambda> at 0x322d84b80>, lambda x0, x1, *params :params[0]*(params[2]*x0 + params[5]*x1**2 + params[3]*x1 + params[7]*np.sin(params[8]*x0) - params[11])**2 + params[4]*np.exp(params[1]*x0 + params[10]*x1**2 + params[6]*x1 + params[9]*np.sin(params[8]*x0)).
# 2025-04-12 13:42:17,855 - LLMLEx.kanLEx - INFO - Refitting, new n_chi2: 2.0077e-14 for params[0]*(params[2]*x0 + params[5]*x1**2 + params[3]*x1 + params[7]*np.sin(params[8]*x0) - params[11])**2 + params[4]*np.exp(params[1]*x0 + params[10]*x1**2 + params[6]*x1 + params[9]*np.sin(params[8]*x0))
# 2025-04-12 13:42:17,855 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: -0.0000*(0.0098*x0 + 0.5550*x1**2 + 0.0002*x1 + 0.2772*sp.sin(3.1416*x0) - 0.8709)**2 + 1.0000*sp.exp(0.0000*x0 + 1.0000*x1**2 + 0.0000*x1 + 1.0000*sp.sin(3.1416*x0))
# 2025-04-12 13:42:17,924 - LLMLEx.kanLEx - INFO - Pruning small terms, smaller than 1e-06
# 2025-04-12 13:42:17,925 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 0.0000000000000000*(0.0098408224566650*x0 + 0.5549725078303882*x1**2 + 0.0002309381238370*x1 + 0.2772325047804855*sp.sin(3.1415927748813757*x0) - 0.8709243343339198)**2 + 1.0000000043352415*sp.exp(0.0000000000000000*x0 + 0.9999999934745544*x1**2 + 0.0000000000000000*x1 + 0.9999999756501755*sp.sin(3.1415927748813757*x0))
# 2025-04-12 13:42:18,251 - LLMLEx.kanLEx - INFO - Expression (refitted vs refitted and pruned) maintains similar n_chi2: 5.5430e+00
# 2025-04-12 13:42:18,251 - LLMLEx.kanLEx - INFO - raw refitted and pruned expression (n_chi2: 5.5430e+00): 1*exp(1*x1**2 + 1*sin(3.142*x0))
# 2025-04-12 13:42:18,252 - LLMLEx.kanLEx - INFO - Current best result:
# 2025-04-12 13:42:18,252 - LLMLEx.kanLEx - INFO - fit_type: rawrefitted
# 2025-04-12 13:42:18,252 - LLMLEx.kanLEx - INFO - n_chi_squared: 5.543022632598877
# 2025-04-12 13:42:18,253 - LLMLEx.kanLEx - INFO - expression: 1.00000000433524*exp(0.999999993474554*x1**2 + 0.999999975650176*sin(3.14159277488138*x0))
# 2025-04-12 13:42:18,253 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 prompts, each with 3 answers. Will attempt this process 2 times.
# 2025-04-12 13:42:18,253 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 answers per prompt for 3 prompts. We are on attempt #1
# 2025-04-12 13:42:18,253 - LLMLEx.kanLEx - INFO - Using default system prompt for LLM simplification
# 2025-04-12 13:42:19,865 - LLMLEx.kanLEx - INFO - LLM improvement responses (3 answers per prompt for 3 prompts, 9 responses, using 9): ['exp(x1**2 + 3.142*x0 - (3.142**3 / 6)*x0**3)', 'exp(x1**2 + 3.142*x0)', 'exp(x1**2)', 'exp(x1**2 + 3.142*x0)', 'exp(x1**2 + x0)', 'exp(x1**2 + (3.142*x0 - (3.142**3 * x0**3) / 6))', 'exp(x1**2 + 1)', 'exp(x1**2 + 3.142*x0)', 'exp(x1**2)']
# 2025-04-12 13:42:19,866 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #1: exp(x1**2 + 3.142*x0 - (3.142**3 / 6)*x0**3)
# 2025-04-12 13:42:20,041 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 without fitting: 7.6320e+00
# 2025-04-12 13:42:20,587 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 after fitting: 2.8416e-02 for lambda x0, x1, *params :np.exp(params[0]*x0**3 + params[1]*x0 + x1**2), params opt.: [-2.9863546  2.7245286...
# 2025-04-12 13:42:20,587 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(-2.9863545894622803*x0**3 + 2.7245285511016846*x0 + x1**2)
# 2025-04-12 13:42:20,625 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #2: exp(x1**2 + 3.142*x0)
# 2025-04-12 13:42:20,754 - LLMLEx.kanLEx - INFO - LLM prompt number #2 n_chi2 without fitting: 1.2491e+02
# 2025-04-12 13:42:21,352 - LLMLEx.kanLEx - INFO - LLM prompt number #2 n_chi2 after fitting: 1.2541e+00 for lambda x0, x1, *params :np.exp(params[0]*x0 + x1**2), params opt.: [0.87923499...
# 2025-04-12 13:42:21,353 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(0.8792349923728929*x0 + x1**2)
# 2025-04-12 13:42:21,370 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #3: exp(x1**2)
# 2025-04-12 13:42:21,498 - LLMLEx.kanLEx - INFO - LLM prompt number #3 n_chi2 without fitting: 3.3136e+00
# 2025-04-12 13:42:21,544 - LLMLEx.kanLEx - INFO - LLM prompt number #3 n_chi2 after fitting: 2.5215e+00 for lambda x0, x1, *params :np.exp(x1**2), params opt.: [...
# 2025-04-12 13:42:21,545 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(x1**2)
# 2025-04-12 13:42:21,551 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #4: exp(x1**2 + 3.142*x0)
# 2025-04-12 13:42:21,683 - LLMLEx.kanLEx - INFO - LLM prompt number #4 n_chi2 without fitting: 1.2491e+02
# 2025-04-12 13:42:22,012 - LLMLEx.kanLEx - INFO - LLM prompt number #4 n_chi2 after fitting: 1.2541e+00 for lambda x0, x1, *params :np.exp(params[0]*x0 + x1**2), params opt.: [0.87923499...
# 2025-04-12 13:42:22,012 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(0.8792349923728929*x0 + x1**2)
# 2025-04-12 13:42:22,016 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #5: exp(x1**2 + x0)
# 2025-04-12 13:42:22,144 - LLMLEx.kanLEx - INFO - LLM prompt number #5 n_chi2 without fitting: 4.7020e+00
# 2025-04-12 13:42:22,180 - LLMLEx.kanLEx - INFO - LLM prompt number #5 n_chi2 after fitting: 1.2964e+00 for lambda x0, x1, *params :np.exp(x0 + x1**2), params opt.: [...
# 2025-04-12 13:42:22,180 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(x0 + x1**2)
# 2025-04-12 13:42:22,192 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #6: exp(x1**2 + (3.142*x0 - (3.142**3 * x0**3) / 6))
# 2025-04-12 13:42:22,320 - LLMLEx.kanLEx - INFO - LLM prompt number #6 n_chi2 without fitting: 7.6320e+00
# 2025-04-12 13:42:22,667 - LLMLEx.kanLEx - INFO - LLM prompt number #6 n_chi2 after fitting: 2.8416e-02 for lambda x0, x1, *params :np.exp(params[0]*x0**3 + params[1]*x0 + x1**2), params opt.: [-2.9863546  2.7245286...
# 2025-04-12 13:42:22,668 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(-2.9863545894622803*x0**3 + 2.7245285511016846*x0 + x1**2)
# 2025-04-12 13:42:22,674 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #7: exp(x1**2 + 1)
# 2025-04-12 13:42:22,803 - LLMLEx.kanLEx - INFO - LLM prompt number #7 n_chi2 without fitting: 1.1710e+01
# 2025-04-12 13:42:22,839 - LLMLEx.kanLEx - INFO - LLM prompt number #7 n_chi2 after fitting: 9.5566e+00 for lambda x0, x1, *params :np.exp(x1**2 + 1), params opt.: [...
# 2025-04-12 13:42:22,839 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(x1**2 + 1)
# 2025-04-12 13:42:22,847 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #8: exp(x1**2 + 3.142*x0)
# 2025-04-12 13:42:22,980 - LLMLEx.kanLEx - INFO - LLM prompt number #8 n_chi2 without fitting: 1.2491e+02
# 2025-04-12 13:42:23,311 - LLMLEx.kanLEx - INFO - LLM prompt number #8 n_chi2 after fitting: 1.2541e+00 for lambda x0, x1, *params :np.exp(params[0]*x0 + x1**2), params opt.: [0.87923499...
# 2025-04-12 13:42:23,311 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(0.8792349923728929*x0 + x1**2)
# 2025-04-12 13:42:23,315 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #9: exp(x1**2)
# 2025-04-12 13:42:23,441 - LLMLEx.kanLEx - INFO - LLM prompt number #9 n_chi2 without fitting: 3.3136e+00
# 2025-04-12 13:42:23,476 - LLMLEx.kanLEx - INFO - LLM prompt number #9 n_chi2 after fitting: 2.5215e+00 for lambda x0, x1, *params :np.exp(x1**2), params opt.: [...
# 2025-04-12 13:42:23,477 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: sp.exp(x1**2)
# 2025-04-12 13:42:23,479 - LLMLEx.kanLEx - INFO - Final LLM response, n_chi2 2.8416e-02 simplified and refitted: exp(-2.986*x0**3 + 2.725*x0 + x1**2), from model response exp(x1**2 + 3.142*x0 - (3.142**3 / 6)*x0**3)
# 2025-04-12 13:42:23,479 - LLMLEx.kanLEx - ERROR - Plotting all results for output 0 with 2 inputs is not supported for more than 1 input. Skipping plot. If Ninputs ==2, use self.plot_results()
# 2025-04-12 13:42:23,479 - LLMLEx.kanLEx - INFO -
# ###############################
# # Raw and Refitted Results for output 0 (4sf): #
# ###############################
# 2025-04-12 13:42:23,479 - LLMLEx.kanLEx - INFO - Raw expression n_chi2 5.579e+00: -0.04207*(0.004301*x0 + 0.6278*x1**2 + 0.0002223*x1 + 0.627*sin(3.146*x0) - 1)**2 + 0.9161*exp(0.007105*x0 + 1.037*x1**2 + 0.0003673*x1 + 1.036*sin(3.146*x0))
# 2025-04-12 13:42:23,480 - LLMLEx.kanLEx - INFO - Refitted expression n_chi2 5.543e+00: 1*exp(1*x1**2 + 1*sin(3.142*x0))
# 2025-04-12 13:42:23,480 - LLMLEx.kanLEx - INFO - Best LLM expression n_chi2 2.842e-02: exp(-2.986*x0**3 + 2.725*x0 + x1**2)
# 2025-04-12 13:42:23,480 - LLMLEx.kanLEx - INFO -
# ###############################
# # Final formula for output 0: #
# ###############################
# 2025-04-12 13:42:23,481 - LLMLEx.kanLEx - INFO - Best expression n_chi2 2.842e-02 from LLMsimplified fit: np.exp(-2.98635458946228*x0**3 + 2.72452855110168*x0 + x1**2)
# 2025-04-12 13:42:23,481 - LLMLEx.kanLEx - INFO - Round to 4sf: np.exp(-2.986*x0**3 + 2.725*x0 + x1**2)
# 2025-04-12 13:42:23,481 - LLMLEx.kanLEx - INFO -
# ###############################
# # Top 10 Best Fits for Output 0 #
# ###############################
# 2025-04-12 13:42:23,482 - LLMLEx.kanLEx - INFO - Chi²            Type                           Expression (rounded to 4sf)
# 2025-04-12 13:42:23,482 - LLMLEx.kanLEx - INFO - ------------------------------------------------------------------------------------------
# 2025-04-12 13:42:23,482 - LLMLEx.kanLEx - INFO - 2.842e-02       LLMsimplified                  exp(-2.986*x0**3 + 2.725*x0 + x1**2)
# 2025-04-12 13:42:23,482 - LLMLEx.kanLEx - INFO - 2.842e-02       LLMsimplified_attempt_0_answer_6 exp(-2.986*x0**3 + 2.725*x0 + x1**2)
# 2025-04-12 13:42:23,483 - LLMLEx.kanLEx - INFO - 1.254e+00       LLMsimplified_attempt_0_answer_2 exp(0.8792*x0 + x1**2)
# 2025-04-12 13:42:23,483 - LLMLEx.kanLEx - INFO - 1.254e+00       LLMsimplified_attempt_0_answer_4 exp(0.8792*x0 + x1**2)
# 2025-04-12 13:42:23,483 - LLMLEx.kanLEx - INFO - 1.254e+00       LLMsimplified_attempt_0_answer_8 exp(0.8792*x0 + x1**2)
# 2025-04-12 13:42:23,483 - LLMLEx.kanLEx - INFO - 1.296e+00       LLMsimplified_attempt_0_answer_5 exp(x0 + x1**2)
# 2025-04-12 13:42:23,484 - LLMLEx.kanLEx - INFO - 2.522e+00       LLMsimplified_attempt_0_answer_3 exp(x1**2)
# 2025-04-12 13:42:23,484 - LLMLEx.kanLEx - INFO - 2.522e+00       LLMsimplified_attempt_0_answer_9 exp(x1**2)
# 2025-04-12 13:42:23,484 - LLMLEx.kanLEx - INFO - 5.543e+00       rawrefitted                    1*exp(1*x1**2 + 1*sin(3.142*x0))
# 2025-04-12 13:42:23,484 - LLMLEx.kanLEx - INFO - 5.579e+00       raw                            -0.04207*(0.004301*x0 + 0.6278*x1**2 + 0.0002223*x1 + 0.627*sin(3.146*x0) - 1)**2 + 0.9161*exp(0.007105*x0 + 1.037*x1**2 + 0.0003673*x1 + 1.036*sin(3.146*x0))
# 2025-04-12 13:42:23,630 - LLMLEx.kanLEx - INFO - API key usage whilst this get_symbolic was running: $0.00

# %%
best_expressions
# Out:
# ['np.exp(-2.98635458946228*x0**3 + 2.72452855110168*x0 + x1**2)']

# %% [markdown]
# # Example 2

# %%
def multivariate_function(x):
    return x[:,[0]] * x[:,[1]]

# Initialize a KANSR instance for the multivariate function
multivariate_kansr = KANLEX(
    client=client,
    width=[2, 1, 1],
    grid=7,
    k=3,
    seed=0
)

multivariate_dataset = multivariate_kansr.create_dataset(
    f=multivariate_function,
    ranges=(1, 2),
    n_var=2,
    train_num=10000,
    test_num=1000
)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
multivariate_kansr.train_kan(
    dataset=multivariate_dataset,
    opt="LBFGS",
    steps=50,
    prune=True,
    node_th=0.2,
    edge_th=0.2
)
# Out:
# 2025-04-25 13:53:23,856 - LLMLEx.kanLEx - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 7.40e-06 | test_loss: 6.99e-06 | reg: 7.52e+00 | : 100%|█| 50/50 [00:04<00:00, 10.71it
# 2025-04-25 13:53:28,709 - LLMLEx.kanLEx - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-04-25 13:53:28,717 - LLMLEx.kanLEx - INFO - Pruned model:
# saving model version 0.1
# Unpruned model. Pruning? True
# saving model version 0.2
# 2025-04-25 13:53:28,890 - LLMLEx.kanLEx - INFO - Final train loss: 7.401979019050486e-06
# 7.401979019050486e-06

# %%
best_expressions, best_chi_squareds, results_dicts, results_all_dicts = multivariate_kansr.get_symbolic(
    client=client,
    population=5,
    generations=2,
    temperature=0.1,
    gpt_model="openai/gpt-5-nano-2025-08-07",
    verbose=1,
    use_async=True,
    plot_fit=True,
    plot_parents=True,
    demonstrate_parent_plotting=True
)
# Out:
# 2025-04-12 13:42:29,451 - LLMLEx.kanLEx - WARNING - Using default exit condition of 0.001. Consider passing 'overall_nchi_squared'as an exit condition - this is the n_chi_squared of the entire model on its inputs. It's not the default as this is not necessarily meaningful for each individual activation function.
# 2025-04-12 13:42:29,451 - LLMLEx.kanLEx - INFO - Converting KAN model to symbolic expressions (exit_condition=0.001)
# 2025-04-12 13:42:29,557 - llmlex.llmlex - INFO - Processing KAN model connections
# 2025-04-12 13:42:29,558 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,0,0)
# 2025-04-12 13:42:29,632 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,0,0)
# 2025-04-12 13:42:29,634 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.3278650045394897, for constant: [0.77032725]
# 2025-04-12 13:42:29,634 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:42:34,024 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-04-12 13:42:34,025 - llmlex.llmlex - INFO - Initial population best: score=-5.0789119437899544e-11, params=[1.15790343 0.33000394], ansatz: params[0] * np.log(x) + params[1]...
# 2025-04-12 13:42:34,026 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-04-12 13:42:34,026 - llmlex.llmlex - INFO - Successfully found expression for connection (0,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 1
#   Success rate: 83.33%
#
# Breakdown by processing stage:
#   Api Call: 6 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 6 succeeded, 0 failed (100.00% success)
#   Function Conversion: 6 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 1 failed (83.33% success)
#
# Error types:
#   Fitting Errors:
#     - numerical error: 1
# Approximation for (0,0,0): params[0] * np.log(x) + params[1], with score -5.0789119437899544e-11 and parameters [1.158 0.33 ]
# 2025-04-12 13:42:34,129 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,1,0)
# 2025-04-12 13:42:34,191 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,1,0)
# 2025-04-12 13:42:34,192 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.3255640268325806, for constant: [0.79751974]
# 2025-04-12 13:42:34,193 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:42:35,569 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-04-12 13:42:37,046 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-04-12 13:42:37,047 - llmlex.llmlex - INFO - Initial population best: score=-4.18999765439132e-11, params=[1.15790257 0.3557965 ], ansatz: params[0] * np.log(x) + params[1]...
# 2025-04-12 13:42:37,048 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-04-12 13:42:37,049 - llmlex.llmlex - INFO - Successfully found expression for connection (0,1,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 1
#   Success rate: 83.33%
#
# Breakdown by processing stage:
#   Api Call: 6 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 1 failed (83.33% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 1
# Approximation for (0,1,0): params[0] * np.log(x) + params[1], with score -4.18999765439132e-11 and parameters [1.158 0.356]
# 2025-04-12 13:42:37,151 - llmlex.llmlex - INFO - Processing non-symbolic activation function (1,0,0)
# 2025-04-12 13:42:37,220 - llmlex.llmlex - INFO - Running genetic algorithm for connection (1,0,0)
# 2025-04-12 13:42:37,222 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.9336795806884766, for constant: [2.22809194]
# 2025-04-12 13:42:37,222 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-04-12 13:42:38,365 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't help with that.'
# 2025-04-12 13:42:40,349 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-04-12 13:42:40,350 - llmlex.llmlex - INFO - Initial population best: score=-2.056555759022416e-10, params=[0.55306724 0.86362891], ansatz: params[0] * np.exp(params[1] * x)...
# 2025-04-12 13:42:40,351 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-04-12 13:42:40,351 - llmlex.llmlex - INFO - Successfully found expression for connection (1,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 1
#   Success rate: 83.33%
#
# Breakdown by processing stage:
#   Api Call: 6 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 1 failed (83.33% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 1
# Approximation for (1,0,0): params[0] * np.exp(params[1] * x), with score -2.056555759022416e-10 and parameters [0.553 0.864]
# 2025-04-12 13:42:40,454 - llmlex.llmlex - INFO - KAN conversion complete: 3 total connections
# 2025-04-12 13:42:40,455 - llmlex.llmlex - INFO - Connection breakdown: 0 symbolic, 0 zero, 3 processed
# 2025-04-12 13:42:40,572 - llmlex.llmlex - INFO - API key usage whilst this kan_to_symbolic was running: $0.00
# 2025-04-12 13:42:40,573 - LLMLEx.kanLEx - INFO - Approximation for (0, 0, 0): params[0] * np.log(x) + params[1], has parameters [1.2 0.3]
# 2025-04-12 13:42:40,573 - LLMLEx.kanLEx - INFO - Approximation for (0, 1, 0): params[0] * np.log(x) + params[1], has parameters [1.2 0.4]
# 2025-04-12 13:42:40,574 - LLMLEx.kanLEx - INFO - Approximation for (1, 0, 0): params[0] * np.exp(params[1] * x), has parameters [0.6 0.9]
# 2025-04-12 13:42:40,575 - LLMLEx.kanLEx - INFO - Building expression tree
# 2025-04-12 13:42:40,576 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 0, 0), Best Expression: 1.1579034312693057 * np.log(1. * x ) + 0.3300039375139140, Score: -0.00000
# 2025-04-12 13:42:40,578 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 1, 0), Best Expression: 1.1579025692801030 * np.log(1. * x ) + 0.3557965042776813, Score: -0.00000
# 2025-04-12 13:42:40,578 - LLMLEx.kanLEx - INFO - KAN Connection: (1, 0, 0), Best Expression: 0.5530672406791013 * np.exp(0.8636289119646535 * x ), Score: -0.00000
# 2025-04-12 13:42:40,579 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 0.5530672406791013 * sp.exp(0.8636289119646535 * (1.1579034312693057 * sp.log(1. * x0 ) + 0.3300039375139140 + 1.1579025692801030 * sp.log(1. * x1 ) + 0.3557965042776813) )
# 2025-04-12 13:42:40,591 - LLMLEx.kanLEx - INFO -
# ###################################################
# 2025-04-12 13:42:40,592 - LLMLEx.kanLEx - INFO - Simplifying output 0 using openai/gpt-5-nano-2025-08-07 and sympy
# 2025-04-12 13:42:40,780 - LLMLEx.kanLEx - INFO - KAN expression (raw), n_chi2 with original data: 3.9523e+00: 1*x0**1*x1**1
# 2025-04-12 13:42:40,780 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 1.0000013970668600*x0**0.9999988805072491*x1**0.9999981360684520
# 2025-04-12 13:42:41,116 - LLMLEx.kanLEx - INFO - Expression (raw expression (simplified)) maintains similar n_chi2: 3.9523e+00
# 2025-04-12 13:42:41,129 - LLMLEx.kanLEx - INFO - Refitting simplified expression, trying to improve n_chi2 from 3.9523e+00, params[2]*x0**params[1]*x1**params[0], [0.999998136068452, 0.999998880507249, 1.00000139706686], <function <lambda> at 0x17dd38900>, lambda x0, x1, *params :params[2]*x0**params[1]*x1**params[0].
# 2025-04-12 13:42:41,792 - LLMLEx.kanLEx - INFO - Refitting, new n_chi2: 0.0000e+00 for params[2]*x0**params[1]*x1**params[0]
# 2025-04-12 13:42:41,793 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 1.0000*x0**1.0000*x1**1.0000
# 2025-04-12 13:42:41,798 - LLMLEx.kanLEx - INFO - Pruning small terms, smaller than 1e-06
# 2025-04-12 13:42:41,798 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 1.0000000003210143*x0**0.9999999993926391*x1**0.9999999985918786
# 2025-04-12 13:42:42,100 - LLMLEx.kanLEx - INFO - Expression (refitted vs refitted and pruned) maintains similar n_chi2: 3.9523e+00
# 2025-04-12 13:42:42,101 - LLMLEx.kanLEx - INFO - raw refitted and pruned expression (n_chi2: 3.9523e+00): 1*x0**1*x1**1
# 2025-04-12 13:42:42,101 - LLMLEx.kanLEx - INFO - Current best result:
# 2025-04-12 13:42:42,101 - LLMLEx.kanLEx - INFO - fit_type: raw
# 2025-04-12 13:42:42,102 - LLMLEx.kanLEx - INFO - n_chi_squared: 3.952286958694458
# 2025-04-12 13:42:42,102 - LLMLEx.kanLEx - INFO - expression: 1.00000139706686*x0**0.999998880507249*x1**0.999998136068452
# 2025-04-12 13:42:42,102 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 prompts, each with 3 answers. Will attempt this process 2 times.
# 2025-04-12 13:42:42,103 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 answers per prompt for 3 prompts. We are on attempt #1
# 2025-04-12 13:42:42,103 - LLMLEx.kanLEx - INFO - Using default system prompt for LLM simplification
# 2025-04-12 13:42:43,263 - LLMLEx.kanLEx - INFO - LLM improvement responses (3 answers per prompt for 3 prompts, 9 responses, using 9): ['x0*x1', 'x0**(0.5+0.5)*x1**(0.5+0.5)', 'x0*(x1**0.5)**2', 'x0*x1', 'x0**1*x1', 'x0*x1**1', 'x0*x1', 'x0**1*x1', 'x0*x1**1']
# 2025-04-12 13:42:43,263 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #1: x0*x1
# 2025-04-12 13:42:43,456 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 without fitting: 3.9523e+00
# 2025-04-12 13:42:43,491 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 after fitting: 0.0000e+00 for lambda x0, x1, *params :x0*x1, params opt.: [...
# 2025-04-12 13:42:43,492 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0*x1
# 2025-04-12 13:42:43,494 - LLMLEx.kanLEx - INFO - Found excellent fit with n_chi_squared < 1e-6: 0.0000e+00
# 2025-04-12 13:42:43,494 - LLMLEx.kanLEx - INFO - Final LLM response, n_chi2 0.0000e+00 simplified and refitted: x0*x1, from model response x0*x1
# 2025-04-12 13:42:43,495 - LLMLEx.kanLEx - ERROR - Plotting all results for output 0 with 2 inputs is not supported for more than 1 input. Skipping plot. If Ninputs ==2, use self.plot_results()
# 2025-04-12 13:42:43,495 - LLMLEx.kanLEx - INFO -
# ###############################
# # Raw and Refitted Results for output 0 (4sf): #
# ###############################
# 2025-04-12 13:42:43,495 - LLMLEx.kanLEx - INFO - Raw expression n_chi2 3.952e+00: 1*x0**1*x1**1
# 2025-04-12 13:42:43,496 - LLMLEx.kanLEx - INFO - Refitted expression n_chi2 3.952e+00: 1*x0**1*x1**1
# 2025-04-12 13:42:43,496 - LLMLEx.kanLEx - INFO - Best LLM expression n_chi2 0.000e+00: x0*x1
# 2025-04-12 13:42:43,496 - LLMLEx.kanLEx - INFO -
# ###############################
# # Final formula for output 0: #
# ###############################
# 2025-04-12 13:42:43,497 - LLMLEx.kanLEx - INFO - Best expression n_chi2 0.000e+00 from LLMsimplified fit: x0*x1
# 2025-04-12 13:42:43,497 - LLMLEx.kanLEx - INFO - Round to 4sf: x0*x1
# 2025-04-12 13:42:43,497 - LLMLEx.kanLEx - INFO -
# ###############################
# # Top 10 Best Fits for Output 0 #
# ###############################
# 2025-04-12 13:42:43,497 - LLMLEx.kanLEx - INFO - Chi²            Type                           Expression (rounded to 4sf)
# 2025-04-12 13:42:43,498 - LLMLEx.kanLEx - INFO - ------------------------------------------------------------------------------------------
# 2025-04-12 13:42:43,498 - LLMLEx.kanLEx - INFO - 0.000e+00       LLMsimplified                  x0*x1
# 2025-04-12 13:42:43,498 - LLMLEx.kanLEx - INFO - 3.952e+00       raw                            1*x0**1*x1**1
# 2025-04-12 13:42:43,498 - LLMLEx.kanLEx - INFO - 3.952e+00       rawrefitted                    1*x0**1*x1**1
# 2025-04-12 13:42:43,616 - LLMLEx.kanLEx - INFO - API key usage whilst this get_symbolic was running: $0.00

# %%
best_expressions, best_chi_squareds
# Out:
# (['x0*x1'], [0.0])

# %% [markdown]
# # Example 3

# %%
def multivariate_function(x):
    return x[:,0]*x[:,1]/x[:,2]

# Initialize a KANSR instance for the multivariate function
multivariate_kansr = KANLEX(
    client=client,
    width=[3, 4, 4, 1],
    grid=7,
    k=3,
    seed=0
)

multivariate_dataset = multivariate_kansr.create_dataset(
    f=multivariate_function,
    ranges=(0.5, 3),
    n_var=3,
    train_num=10000,
    test_num=1000
)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
multivariate_kansr.train_kan(
    dataset=multivariate_dataset,
    opt="LBFGS",
    steps=50,
    prune=True,
    node_th=0.2,
    edge_th=0.2
)
# Out:
# 2025-05-02 13:38:17,606 - LLMLEx.kanLEx - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 2.37e-03 | test_loss: 2.37e-03 | reg: 2.13e+01 | : 100%|█| 50/50 [00:31<00:00,  1.60it
# saving model version 0.1
# Unpruned model. Pruning? True
# 2025-05-02 13:38:50,885 - LLMLEx.kanLEx - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-05-02 13:38:50,903 - LLMLEx.kanLEx - INFO - Pruned model:
# saving model version 0.2
# 2025-05-02 13:38:51,484 - LLMLEx.kanLEx - INFO - Final train loss: 0.002374607138335705
# 0.002374607138335705

# %%
def multivariate_function(x):
    return x[:,0]*x[:,1]/x[:,2]

# Initialize a KANSR instance for the multivariate function
multivariate_kansr = KANLEX(
    client=client,
    width=[3, 2, 2, 1],
    grid=7,
    k=3,
    seed=0
)

multivariate_dataset = multivariate_kansr.create_dataset(
    f=multivariate_function,
    ranges=(0.5, 3),
    n_var=3,
    train_num=10000,
    test_num=1000
)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
multivariate_kansr.train_kan(
    dataset=multivariate_dataset,
    opt="LBFGS",
    steps=50,
    prune=True,
    node_th=0.2,
    edge_th=0.2
)
# Out:
# 2025-05-02 13:40:32,065 - LLMLEx.kanLEx - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 1.92e-02 | test_loss: 2.20e-02 | reg: 2.29e+01 | : 100%|█| 50/50 [00:14<00:00,  3.57it
# saving model version 0.1
# Unpruned model. Pruning? True
# 2025-05-02 13:40:46,755 - LLMLEx.kanLEx - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-05-02 13:40:46,766 - LLMLEx.kanLEx - INFO - Pruned model:
# saving model version 0.2
# 2025-05-02 13:40:47,055 - LLMLEx.kanLEx - INFO - Final train loss: 0.019212543964385986
# 0.019212543964385986

# %%
def multivariate_function(x):
    return x[:,0]*x[:,1]/x[:,2]

# Initialize a KANSR instance for the multivariate function
multivariate_kansr = KANLEX(
    client=client,
    width=[3, 1, 1],
    grid=7,
    k=3,
    seed=0
)

multivariate_dataset = multivariate_kansr.create_dataset(
    f=multivariate_function,
    ranges=(0.5, 3),
    n_var=3,
    train_num=10000,
    test_num=1000
)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
multivariate_kansr.train_kan(
    dataset=multivariate_dataset,
    opt="LBFGS",
    steps=50,
    prune=True,
    node_th=0.2,
    edge_th=0.2
)
# Out:
# 2025-05-02 13:41:20,560 - LLMLEx.kanLEx - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 1.11e-02 | test_loss: 1.19e-02 | reg: 1.06e+01 | : 100%|█| 50/50 [00:05<00:00,  8.79it
# saving model version 0.1
# Unpruned model. Pruning? True
# 2025-05-02 13:41:26,483 - LLMLEx.kanLEx - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-05-02 13:41:26,491 - LLMLEx.kanLEx - INFO - Pruned model:
# saving model version 0.2
# 2025-05-02 13:41:26,727 - LLMLEx.kanLEx - INFO - Final train loss: 0.011090999469161034
# 0.011090999469161034

# %%
best_expressions, best_chi_squareds, results_dicts, results_all_dicts = multivariate_kansr.get_symbolic(
    client=client,
    population=5,
    generations=2,
    temperature=0.1,
    gpt_model="openai/gpt-5-nano-2025-08-07",
    verbose=1,
    use_async=True,
    plot_fit=True,
    plot_parents=True,
    demonstrate_parent_plotting=True
)
# Out:
# 2025-05-02 13:41:40,671 - LLMLEx.kanLEx - WARNING - Using default exit condition of 0.001. Consider passing 'overall_nchi_squared'as an exit condition - this is the n_chi_squared of the entire model on its inputs. It's not the default as this is not necessarily meaningful for each individual activation function.
# 2025-05-02 13:41:40,671 - LLMLEx.kanLEx - INFO - Converting KAN model to symbolic expressions (exit_condition=0.001)
# 2025-05-02 13:41:40,761 - llmlex.llmlex - INFO - Processing KAN model connections
# 2025-05-02 13:41:40,762 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,0,0)
# 2025-05-02 13:41:40,850 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,0,0)
# 2025-05-02 13:41:41,243 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.7326761484146118, for constant: [0.289146]
# 2025-05-02 13:41:41,244 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-05-02 13:41:43,773 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with identifying or verifying data from a photo.'
# 2025-05-02 13:41:44,715 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't analyze or transform the given image directly.'
# 2025-05-02 13:41:44,810 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I cannot fulfill this request.'
# 2025-05-02 13:41:46,581 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-05-02 13:41:48,533 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-05-02 13:41:48,534 - llmlex.llmlex - INFO - Initial population best: score=-0.0004759493167512119, params=[ 2.02875256 -0.60514044], ansatz: params[0] * np.log(x) + params[1]...
# 2025-05-02 13:41:48,535 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-05-02 13:41:48,535 - llmlex.llmlex - INFO - Successfully found expression for connection (0,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 4
#   Success rate: 55.56%
#
# Breakdown by processing stage:
#   Api Call: 9 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 4 failed (55.56% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 4
# Approximation for (0,0,0): params[0] * np.log(x) + params[1], with score -0.0004759493167512119 and parameters [ 2.029 -0.605]
# 2025-05-02 13:41:48,635 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,1,0)
# 2025-05-02 13:41:48,701 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,1,0)
# 2025-05-02 13:41:48,702 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.785326600074768, for constant: [-5.40162802]
# 2025-05-02 13:41:48,703 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-05-02 13:41:52,242 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-05-02 13:41:52,243 - llmlex.llmlex - INFO - Initial population best: score=-1.6971882359939627e-05, params=[ 2.02632899 -6.30206609], ansatz: params[0] * np.log(x) + params[1]...
# 2025-05-02 13:41:52,243 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-05-02 13:41:52,244 - llmlex.llmlex - INFO - Successfully found expression for connection (0,1,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 0
#   Success rate: 100.00%
#
# Breakdown by processing stage:
#   Api Call: 5 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 0 failed (100.00% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   No errors
# Approximation for (0,1,0): params[0] * np.log(x) + params[1], with score -1.6971882359939627e-05 and parameters [ 2.026 -6.302]
# 2025-05-02 13:41:52,343 - llmlex.llmlex - INFO - Processing non-symbolic activation function (0,2,0)
# 2025-05-02 13:41:52,409 - llmlex.llmlex - INFO - Running genetic algorithm for connection (0,2,0)
# 2025-05-02 13:41:52,410 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -1.805428147315979, for constant: [-2.49426775]
# 2025-05-02 13:41:52,411 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-05-02 13:41:53,567 - llmlex.llmlex - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't provide that.'
# 2025-05-02 13:42:00,614 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-05-02 13:42:00,615 - llmlex.llmlex - INFO - Initial population best: score=-0.00014365449897013605, params=[-2.02884715 -1.5466055 ], ansatz: params[0] * np.log(x) + params[1]...
# 2025-05-02 13:42:00,616 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-05-02 13:42:00,616 - llmlex.llmlex - INFO - Successfully found expression for connection (0,2,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 1
#   Success rate: 83.33%
#
# Breakdown by processing stage:
#   Api Call: 6 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 1 failed (83.33% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 1
# Approximation for (0,2,0): params[0] * np.log(x) + params[1], with score -0.00014365449897013605 and parameters [-2.029 -1.547]
# 2025-05-02 13:42:00,714 - llmlex.llmlex - INFO - Processing non-symbolic activation function (1,0,0)
# 2025-05-02 13:42:00,785 - llmlex.llmlex - INFO - Running genetic algorithm for connection (1,0,0)
# 2025-05-02 13:42:00,786 - llmlex.llmlex - INFO - Constant function is not a good fit: Score: -4.907601833343506, for constant: [2.09923838]
# 2025-05-02 13:42:00,787 - llmlex.llmlex - INFO - Generating initial population asynchronously
# 2025-05-02 13:42:05,113 - llmlex.llmlex - INFO - Generated 5 individuals
# 2025-05-02 13:42:05,114 - llmlex.llmlex - INFO - Initial population best: score=-7.604894562973641e-06, params=[ 6.46084612e+01  4.93013765e-01 -6.59570610e-04], ansatz: params[0] * np.exp(params[1] * x) + params[2]...
# 2025-05-02 13:42:05,114 - llmlex.llmlex - INFO - Exit condition met after initial population
# 2025-05-02 13:42:05,115 - llmlex.llmlex - INFO - Successfully found expression for connection (1,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 5
#   Failed calls: 0
#   Success rate: 100.00%
#
# Breakdown by processing stage:
#   Api Call: 5 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 5 succeeded, 0 failed (100.00% success)
#   Function Conversion: 5 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 5 succeeded, 0 failed (100.00% success)
#
# Error types:
#   No errors
#
# Fitting warnings:
#   - other warnings: 13
# Approximation for (1,0,0): params[0] * np.exp(params[1] * x) + params[2], with score -7.604894562973641e-06 and parameters [ 6.4608e+01  4.9300e-01 -1.0000e-03]
# 2025-05-02 13:42:05,215 - llmlex.llmlex - INFO - KAN conversion complete: 4 total connections
# 2025-05-02 13:42:05,215 - llmlex.llmlex - INFO - Connection breakdown: 0 symbolic, 0 zero, 4 processed
# 2025-05-02 13:42:05,433 - llmlex.llmlex - INFO - API key usage whilst this kan_to_symbolic was running: $0.00
# 2025-05-02 13:42:05,434 - LLMLEx.kanLEx - INFO - Approximation for (0, 0, 0): params[0] * np.log(x) + params[1], has parameters [ 2.  -0.6]
# 2025-05-02 13:42:05,434 - LLMLEx.kanLEx - INFO - Approximation for (0, 1, 0): params[0] * np.log(x) + params[1], has parameters [ 2.  -6.3]
# 2025-05-02 13:42:05,435 - LLMLEx.kanLEx - INFO - Approximation for (0, 2, 0): params[0] * np.log(x) + params[1], has parameters [-2.  -1.5]
# 2025-05-02 13:42:05,435 - LLMLEx.kanLEx - INFO - Approximation for (1, 0, 0): params[0] * np.exp(params[1] * x) + params[2], has parameters [64.6  0.5 -0. ]
# 2025-05-02 13:42:05,436 - LLMLEx.kanLEx - INFO - Building expression tree
# 2025-05-02 13:42:05,437 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 0, 0), Best Expression: 2.0287525557613155 * np.log(1. * x ) + -0.6051404380572085, Score: -0.00048
# 2025-05-02 13:42:05,438 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 1, 0), Best Expression: 2.0263289912235125 * np.log(1. * x ) + -6.3020660886865709, Score: -0.00002
# 2025-05-02 13:42:05,438 - LLMLEx.kanLEx - INFO - KAN Connection: (0, 2, 0), Best Expression: -2.0288471495378260 * np.log(1. * x ) + -1.5466055000239067, Score: -0.00014
# 2025-05-02 13:42:05,439 - LLMLEx.kanLEx - INFO - KAN Connection: (1, 0, 0), Best Expression: 64.6084611786890122 * np.exp(0.4930137654070221 * x ) + -0.0006595706096447, Score: -0.00001
# 2025-05-02 13:42:05,441 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 64.6084611786890122 * sp.exp(0.4930137654070221 * (2.0287525557613155 * sp.log(1. * x0 ) - 0.6051404380572085 + 2.0263289912235125 * sp.log(1. * x1 ) - 6.3020660886865709 - 2.0288471495378260 * sp.log(1. * x2 ) - 1.5466055000239067) ) - 0.0006595706096447
# 2025-05-02 13:42:05,541 - LLMLEx.kanLEx - INFO -
# ###################################################
# 2025-05-02 13:42:05,542 - LLMLEx.kanLEx - INFO - Simplifying output 0 using openai/gpt-5-nano-2025-08-07 and sympy
# 2025-05-02 13:42:05,856 - LLMLEx.kanLEx - INFO - KAN expression (raw), n_chi2 with original data: 1.0643e+01: 1*x0**1*x1**0.999/x2**1 - 0.0006596
# 2025-05-02 13:42:05,857 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 1.0004998057113399*x0**1.0002029365950100*x1**0.9990080859165160/x2**1.0002495726289500 - 0.0006595706096447
# 2025-05-02 13:42:06,150 - LLMLEx.kanLEx - INFO - Expression (raw expression (simplified)) maintains similar n_chi2: 1.0643e+01
# 2025-05-02 13:42:06,166 - LLMLEx.kanLEx - INFO - Refitting simplified expression, trying to improve n_chi2 from 1.0643e+01, params[4]*x0**params[3]*x1**params[1]*x2**(params[2]) - params[0], [0.0006595706096447, 0.999008085916516, -1.00024957262895, 1.00020293659501, 1.00049980571134], <function <lambda> at 0x3355ee020>, lambda x0, x1, x2, *params :params[4]*x0**params[3]*x1**params[1]*x2**(params[2]) - params[0].
# 2025-05-02 13:42:07,644 - LLMLEx.kanLEx - INFO - Refitting, new n_chi2: 1.5698e-14 for params[4]*x0**params[3]*x1**params[1]*x2**(params[2]) - params[0]
# 2025-05-02 13:42:07,645 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 1.0000*x0**1.0000*x1**1.0000*x2**(-1.0000) - -0.0000
# 2025-05-02 13:42:07,652 - LLMLEx.kanLEx - INFO - Pruning small terms, smaller than 1e-06
# 2025-05-02 13:42:07,653 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 30 seconds: 0.9999999985173098*x0**0.9999999995020904*x1**1.0000000002025622*x2**(-0.9999999985525309) - 0.0000000000000000
# 2025-05-02 13:42:07,942 - LLMLEx.kanLEx - INFO - Expression (refitted vs refitted and pruned) maintains similar n_chi2: 1.0644e+01
# 2025-05-02 13:42:07,943 - LLMLEx.kanLEx - INFO - raw refitted and pruned expression (n_chi2: 1.0644e+01): 1*x0**1*x1**1/x2**1
# 2025-05-02 13:42:07,944 - LLMLEx.kanLEx - INFO - Current best result:
# 2025-05-02 13:42:07,944 - LLMLEx.kanLEx - INFO - fit_type: raw
# 2025-05-02 13:42:07,944 - LLMLEx.kanLEx - INFO - n_chi_squared: 10.642560958862305
# 2025-05-02 13:42:07,944 - LLMLEx.kanLEx - INFO - expression: 1.00049980571134*x0**1.00020293659501*x1**0.999008085916516/x2**1.00024957262895 - 0.0006595706096447
# 2025-05-02 13:42:07,945 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 prompts, each with 3 answers. Will attempt this process 2 times.
# 2025-05-02 13:42:07,945 - LLMLEx.kanLEx - INFO - LLM simplification step - trying 3 answers per prompt for 3 prompts. We are on attempt #1
# 2025-05-02 13:42:07,946 - LLMLEx.kanLEx - INFO - Using default system prompt for LLM simplification
# 2025-05-02 13:42:11,033 - LLMLEx.kanLEx - INFO - LLM improvement responses (3 answers per prompt for 3 prompts, 9 responses, using 9): ['x0/x2 - 0.0006596', 'x0/(x2) - 0.0006596', 'x0/(x2) - 0.0006596', 'x0/x2 - 0.0006596', '(x0*x1**0.999)/x2 - 0.0006596', 'x0/(x2**1) - 0.0006596', 'x0*x1**0.999/x2 - 0.0006596', 'x0*x1**1/x2 - 0.0006596', 'x0*x1/x2 - 0.0006596']
# 2025-05-02 13:42:11,034 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #1: x0/x2 - 0.0006596
# 2025-05-02 13:42:11,244 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 without fitting: 7.7021e+00
# 2025-05-02 13:42:11,743 - LLMLEx.kanLEx - INFO - LLM prompt number #1 n_chi2 after fitting: 2.4356e+00 for lambda x0, x1, x2, *params :x0/x2 - params[0], params opt.: [-0.95502...
# 2025-05-02 13:42:11,743 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0/x2 - -0.9550200104713440
# 2025-05-02 13:42:11,751 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #2: x0/(x2) - 0.0006596
# 2025-05-02 13:42:11,882 - LLMLEx.kanLEx - INFO - LLM prompt number #2 n_chi2 without fitting: 7.7021e+00
# 2025-05-02 13:42:12,218 - LLMLEx.kanLEx - INFO - LLM prompt number #2 n_chi2 after fitting: 2.4356e+00 for lambda x0, x1, x2, *params :x0/x2 - params[0], params opt.: [-0.95502...
# 2025-05-02 13:42:12,218 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0/x2 - -0.9550200104713440
# 2025-05-02 13:42:12,223 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #3: x0/(x2) - 0.0006596
# 2025-05-02 13:42:12,358 - LLMLEx.kanLEx - INFO - LLM prompt number #3 n_chi2 without fitting: 7.7021e+00
# 2025-05-02 13:42:12,951 - LLMLEx.kanLEx - INFO - LLM prompt number #3 n_chi2 after fitting: 2.4356e+00 for lambda x0, x1, x2, *params :x0/x2 - params[0], params opt.: [-0.95502...
# 2025-05-02 13:42:12,952 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0/x2 - -0.9550200104713440
# 2025-05-02 13:42:12,956 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #4: x0/x2 - 0.0006596
# 2025-05-02 13:42:13,090 - LLMLEx.kanLEx - INFO - LLM prompt number #4 n_chi2 without fitting: 7.7021e+00
# 2025-05-02 13:42:13,443 - LLMLEx.kanLEx - INFO - LLM prompt number #4 n_chi2 after fitting: 2.4356e+00 for lambda x0, x1, x2, *params :x0/x2 - params[0], params opt.: [-0.95502...
# 2025-05-02 13:42:13,444 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0/x2 - -0.9550200104713440
# 2025-05-02 13:42:13,448 - LLMLEx.kanLEx - INFO - Trying LLM simplified expression #5: (x0*x1**0.999)/x2 - 0.0006596
# 2025-05-02 13:42:13,574 - LLMLEx.kanLEx - INFO - LLM prompt number #5 n_chi2 without fitting: 1.0634e+01
# 2025-05-02 13:42:14,160 - LLMLEx.kanLEx - INFO - LLM prompt number #5 n_chi2 after fitting: 0.0000e+00 for lambda x0, x1, x2, *params :x0*x1**params[1]/x2 - params[0], params opt.: [3.6816346e-09 1.0000000e+00...
# 2025-05-02 13:42:14,161 - LLMLEx.kanLEx - INFO - Simplifying with timeout of 10 seconds: x0*x1**1.0000000000000000/x2 - 0.0000000000000000
# 2025-05-02 13:42:14,164 - LLMLEx.kanLEx - INFO - Found excellent fit with n_chi_squared < 1e-6: 0.0000e+00
# 2025-05-02 13:42:14,165 - LLMLEx.kanLEx - INFO - Final LLM response, n_chi2 0.0000e+00 simplified and refitted: x0*x1**1/x2, from model response (x0*x1**0.999)/x2 - 0.0006596
# 2025-05-02 13:42:14,165 - LLMLEx.kanLEx - ERROR - Plotting all results for output 0 with 3 inputs is not supported for more than 1 input. Skipping plot. If Ninputs ==2, use self.plot_results()
# 2025-05-02 13:42:14,165 - LLMLEx.kanLEx - INFO -
# ###############################
# # Raw and Refitted Results for output 0 (4sf): #
# ###############################
# 2025-05-02 13:42:14,166 - LLMLEx.kanLEx - INFO - Raw expression n_chi2 1.064e+01: 1*x0**1*x1**0.999/x2**1 - 0.0006596
# 2025-05-02 13:42:14,166 - LLMLEx.kanLEx - INFO - Refitted expression n_chi2 1.064e+01: 1*x0**1*x1**1/x2**1
# 2025-05-02 13:42:14,166 - LLMLEx.kanLEx - INFO - Best LLM expression n_chi2 0.000e+00: x0*x1**1/x2
# 2025-05-02 13:42:14,167 - LLMLEx.kanLEx - INFO -
# ###############################
# # Final formula for output 0: #
# ###############################
# 2025-05-02 13:42:14,167 - LLMLEx.kanLEx - INFO - Best expression n_chi2 0.000e+00 from LLMsimplified fit: x0*x1**1.0/x2
# 2025-05-02 13:42:14,167 - LLMLEx.kanLEx - INFO - Round to 4sf: x0*x1**1/x2
# 2025-05-02 13:42:14,167 - LLMLEx.kanLEx - INFO -
# ###############################
# # Top 10 Best Fits for Output 0 #
# ###############################
# 2025-05-02 13:42:14,167 - LLMLEx.kanLEx - INFO - Chi²            Type                           Expression (rounded to 4sf)
# 2025-05-02 13:42:14,168 - LLMLEx.kanLEx - INFO - ------------------------------------------------------------------------------------------
# 2025-05-02 13:42:14,168 - LLMLEx.kanLEx - INFO - 0.000e+00       LLMsimplified                  x0*x1**1/x2
# 2025-05-02 13:42:14,168 - LLMLEx.kanLEx - INFO - 2.436e+00       LLMsimplified_attempt_0_answer_1 x0/x2 + 0.955
# 2025-05-02 13:42:14,168 - LLMLEx.kanLEx - INFO - 2.436e+00       LLMsimplified_attempt_0_answer_2 x0/x2 + 0.955
# 2025-05-02 13:42:14,169 - LLMLEx.kanLEx - INFO - 2.436e+00       LLMsimplified_attempt_0_answer_3 x0/x2 + 0.955
# 2025-05-02 13:42:14,169 - LLMLEx.kanLEx - INFO - 2.436e+00       LLMsimplified_attempt_0_answer_4 x0/x2 + 0.955
# 2025-05-02 13:42:14,169 - LLMLEx.kanLEx - INFO - 1.064e+01       raw                            1*x0**1*x1**0.999/x2**1 - 0.0006596
# 2025-05-02 13:42:14,170 - LLMLEx.kanLEx - INFO - 1.064e+01       rawrefitted                    1*x0**1*x1**1/x2**1
# 2025-05-02 13:42:14,258 - LLMLEx.kanLEx - INFO - API key usage whilst this get_symbolic was running: $0.00

# %%
best_expressions, best_chi_squareds
# Out:
# (['x0*x1**1.0/x2'], [0.0])
